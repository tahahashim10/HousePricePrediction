# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8104     -118.22     33.79                28.0       3008.0           629.0
# 19647    -120.84     37.47                11.0       2285.0           499.0
# 2914     -119.08     35.36                12.0       6442.0          1116.0
# 14147    -117.08     32.74                35.0       1434.0           253.0
# 16498    -120.97     37.84                28.0       2368.0           430.0
# ...          ...       ...                 ...          ...             ...
# 13151    -121.53     36.85                23.0       3359.0           725.0
# 9612     -120.47     37.29                16.0        749.0           222.0
# 6845     -118.11     34.07                19.0       3215.0           907.0
# 11760    -121.27     38.74                19.0       3869.0           887.0
# 17821    -121.88     37.37                14.0       6016.0          1404.0
#
#        population  households  median_income ocean_proximity  \
# 8104       2537.0       596.0         2.3000      NEAR OCEAN
# 19647      1468.0       471.0         2.7857          INLAND
# 2914       2966.0      1092.0         4.5791          INLAND
# 14147       753.0       228.0         2.3812      NEAR OCEAN
# 16498      1231.0       403.0         2.8830          INLAND
# ...           ...         ...            ...             ...
# 13151      1862.0       651.0         2.6719          INLAND
# 9612       1277.0       224.0         1.2054          INLAND
# 6845       3072.0       870.0         2.3393       <1H OCEAN
# 11760      2086.0       685.0         2.6065          INLAND
# 17821      3258.0      1316.0         3.5745       <1H OCEAN
#
#        median_house_value
# 8104             137500.0
# 19647            110300.0
# 2914             123400.0
# 14147            135100.0
# 16498            141900.0
# ...                   ...
# 13151            193600.0
# 9612              60900.0
# 6845             202300.0
# 11760            154900.0
# 17821            333700.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data_encoded = pd.get_dummies(train_data)

# %%
train_data_encoded
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8104     -118.22     33.79                28.0       3008.0           629.0
# 19647    -120.84     37.47                11.0       2285.0           499.0
# 2914     -119.08     35.36                12.0       6442.0          1116.0
# 14147    -117.08     32.74                35.0       1434.0           253.0
# 16498    -120.97     37.84                28.0       2368.0           430.0
# ...          ...       ...                 ...          ...             ...
# 13151    -121.53     36.85                23.0       3359.0           725.0
# 9612     -120.47     37.29                16.0        749.0           222.0
# 6845     -118.11     34.07                19.0       3215.0           907.0
# 11760    -121.27     38.74                19.0       3869.0           887.0
# 17821    -121.88     37.37                14.0       6016.0          1404.0
#
#        population  households  median_income  median_house_value  \
# 8104       2537.0       596.0         2.3000            137500.0
# 19647      1468.0       471.0         2.7857            110300.0
# 2914       2966.0      1092.0         4.5791            123400.0
# 14147       753.0       228.0         2.3812            135100.0
# 16498      1231.0       403.0         2.8830            141900.0
# ...           ...         ...            ...                 ...
# 13151      1862.0       651.0         2.6719            193600.0
# 9612       1277.0       224.0         1.2054             60900.0
# 6845       3072.0       870.0         2.3393            202300.0
# 11760      2086.0       685.0         2.6065            154900.0
# 17821      3258.0      1316.0         3.5745            333700.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 8104                           0                       0
# 19647                          0                       1
# 2914                           0                       1
# 14147                          0                       0
# 16498                          0                       1
# ...                          ...                     ...
# 13151                          0                       1
# 9612                           0                       1
# 6845                           1                       0
# 11760                          0                       1
# 17821                          1                       0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 8104                        0                         0
# 19647                       0                         0
# 2914                        0                         0
# 14147                       0                         0
# 16498                       0                         0
# ...                       ...                       ...
# 13151                       0                         0
# 9612                        0                         0
# 6845                        0                         0
# 11760                       0                         0
# 17821                       0                         0
#
#        ocean_proximity_NEAR OCEAN
# 8104                            1
# 19647                           0
# 2914                            0
# 14147                           1
# 16498                           0
# ...                           ...
# 13151                           0
# 9612                            0
# 6845                            0
# 11760                           0
# 17821                           0
#
# [16346 rows x 14 columns]

# %%
train_data.corr(numeric_only = True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924631           -0.112473     0.045283
# latitude            -0.924631  1.000000            0.015348    -0.035444
# housing_median_age  -0.112473  0.015348            1.000000    -0.364852
# total_rooms          0.045283 -0.035444           -0.364852     1.000000
# total_bedrooms       0.068727 -0.065027           -0.321946     0.930810
# population           0.097202 -0.106011           -0.296050     0.853739
# households           0.054742 -0.068921           -0.304732     0.918230
# median_income       -0.014206 -0.080271           -0.120413     0.195513
# median_house_value  -0.047425 -0.142425            0.103899     0.127080
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.068727    0.097202    0.054742      -0.014206
# latitude                 -0.065027   -0.106011   -0.068921      -0.080271
# housing_median_age       -0.321946   -0.296050   -0.304732      -0.120413
# total_rooms               0.930810    0.853739    0.918230       0.195513
# total_bedrooms            1.000000    0.874630    0.978915      -0.011173
# population                0.874630    1.000000    0.905557       0.000611
# households                0.978915    0.905557    1.000000       0.009825
# median_income            -0.011173    0.000611    0.009825       1.000000
# median_house_value        0.042787   -0.030662    0.057801       0.690878
#
#                     median_house_value
# longitude                    -0.047425
# latitude                     -0.142425
# housing_median_age            0.103899
# total_rooms                   0.127080
# total_bedrooms                0.042787
# population                   -0.030662
# households                    0.057801
# median_income                 0.690878
# median_house_value            1.000000

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(numeric_only = True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     7222
# INLAND        5199
# NEAR OCEAN    2122
# NEAR BAY      1799
# ISLAND           4
# Name: ocean_proximity, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 8104           0       0       0         0           1
# 19647          0       1       0         0           0
# 2914           0       1       0         0           0
# 14147          0       0       0         0           1
# 16498          0       1       0         0           0
# ...          ...     ...     ...       ...         ...
# 13151          0       1       0         0           0
# 9612           0       1       0         0           0
# 6845           1       0       0         0           0
# 11760          0       1       0         0           0
# 17821          1       0       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data.join(pd.get_dummies(train_data.ocean_proximity))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8104     -118.22     33.79                28.0     8.009363        6.445720
# 19647    -120.84     37.47                11.0     7.734559        6.214608
# 2914     -119.08     35.36                12.0     8.770750        7.018402
# 14147    -117.08     32.74                35.0     7.268920        5.537334
# 16498    -120.97     37.84                28.0     7.770223        6.066108
# ...          ...       ...                 ...          ...             ...
# 13151    -121.53     36.85                23.0     8.119696        6.587550
# 9612     -120.47     37.29                16.0     6.620073        5.407172
is=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8104     -118.22     33.79                28.0     8.009363        6.445720
# 19647    -120.84     37.47                11.0     7.734559        6.214608
# 2914     -119.08     35.36                12.0     8.770750        7.018402
# 14147    -117.08     32.74                35.0     7.268920        5.537334
# 16498    -120.97     37.84                28.0     7.770223        6.066108
# ...          ...       ...                 ...          ...             ...
# 13151    -121.53     36.85                23.0     8.119696        6.587550
# 9612     -120.47     37.29                16.0     6.620073        5.407172
# 6845     -118.11     34.07                19.0     8.075894        6.811244
# 11760    -121.27     38.74                19.0     8.261010        6.788972
# 17821    -121.88     37.37                14.0     8.702344        7.247793
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 8104     7.839132    6.391917         2.3000            137500.0          0
# 19647    7.292337    6.156979         2.7857            110300.0          0
# 2914     7.995307    6.996681         4.5791            123400.0          0
# 14147    6.625392    5.433722         2.3812            135100.0          0
# 16498    7.116394    6.001415         2.8830            141900.0          0
# ...           ...         ...            ...                 ...        ...
# 13151    7.529943    6.480045         2.6719            193600.0          0
# 9612     7.153052    5.416100         1.2054             60900.0          0
# 6845     8.030410    6.769642         2.3393            202300.0          1
# 11760    7.643483    6.530878         2.6065            154900.0          0
# 17821    8.089176    7.183112         3.5745            333700.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 8104        0       0         0           1
# 19647       1       0         0           0
# 2914        1       0         0           0
# 14147       0       0         0           1
# 16498       1       0         0           0
# ...       ...     ...       ...         ...
# 13151       1       0         0           0
# 9612        1       0         0           0
# 6845        0       0         0           0
# 11760       1       0         0           0
# 17821       0       0         0           0
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(numeric_only = True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize = (15, 8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(numeric_only = True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train, y_train = train_data.drop(['median_house_value'], axis = 1), train_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()

reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
X_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
reg.score(X_test, y_test)
# Out:
# 0.6603585571811574

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.8258025596941467

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [100, 200, 300],
    "min_samples_split": [2, 4],
    "max_depth": [None, 4, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test, y_test)
# Out:
# 0.8268615008838898

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(min_samples_split=4, n_estimators=300)

# %%
grid_search.best_estimator_.score(X_test, y_test)
# Out:
# 0.8268615008838898
