# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0        -122.23     37.88                41.0        880.0           129.0  \
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value
# 0           322.0       126.0         8.3252            452600.0  \
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0        -122.23     37.88                41.0        880.0           129.0  \
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 2728     -115.55     32.79                23.0       1004.0           221.0  \
# 5597     -118.23     33.80                26.0        239.0           135.0
# 8974     -118.41     34.01                26.0       2503.0           449.0
# 1138     -121.56     39.69                 8.0       2836.0           522.0
# 14853    -117.08     32.66                43.0       1004.0           236.0
# ...          ...       ...                 ...          ...             ...
# 4837     -118.29     34.03                42.0       1680.0           557.0
# 17720    -121.78     37.34                11.0       3195.0           410.0
# 1329     -121.88     38.00                16.0       2605.0           440.0
# 13362    -117.61     34.02                 8.0         63.0             9.0
# 14496    -117.19     32.85                15.0       2895.0           498.0
#
#        population  households  median_income ocean_proximity
# 2728        697.0       201.0         1.6351          INLAND  \
# 5597        165.0       112.0         1.3333      NEAR OCEAN
# 8974       1218.0       426.0         5.3683       <1H OCEAN
# 1138       1163.0       512.0         3.1300          INLAND
# 14853       839.0       235.0         2.8100      NEAR OCEAN
# ...           ...         ...            ...             ...
# 4837       2099.0       526.0         1.9167       <1H OCEAN
# 17720      1774.0       418.0         7.0671       <1H OCEAN
# 1329       1352.0       408.0         4.1947          INLAND
# 13362        25.0         7.0         7.7197          INLAND
# 14496      1164.0       443.0         5.1020      NEAR OCEAN
#
#        median_house_value
# 2728              59600.0
# 5597             187500.0
# 8974             500001.0
# 1138             168300.0
# 14853            103400.0
# ...                   ...
# 4837             136400.0
# 17720            378200.0
# 1329             140300.0
# 13362            275000.0
# 14496            417500.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data_encoded = pd.get_dummies(train_data)

# %%
train_data_encoded
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 2728     -115.55     32.79                23.0       1004.0           221.0  \
# 5597     -118.23     33.80                26.0        239.0           135.0
# 8974     -118.41     34.01                26.0       2503.0           449.0
# 1138     -121.56     39.69                 8.0       2836.0           522.0
# 14853    -117.08     32.66                43.0       1004.0           236.0
# ...          ...       ...                 ...          ...             ...
# 4837     -118.29     34.03                42.0       1680.0           557.0
# 17720    -121.78     37.34                11.0       3195.0           410.0
# 1329     -121.88     38.00                16.0       2605.0           440.0
# 13362    -117.61     34.02                 8.0         63.0             9.0
# 14496    -117.19     32.85                15.0       2895.0           498.0
#
#        population  households  median_income  median_house_value
# 2728        697.0       201.0         1.6351             59600.0  \
# 5597        165.0       112.0         1.3333            187500.0
# 8974       1218.0       426.0         5.3683            500001.0
# 1138       1163.0       512.0         3.1300            168300.0
# 14853       839.0       235.0         2.8100            103400.0
# ...           ...         ...            ...                 ...
# 4837       2099.0       526.0         1.9167            136400.0
# 17720      1774.0       418.0         7.0671            378200.0
# 1329       1352.0       408.0         4.1947            140300.0
# 13362        25.0         7.0         7.7197            275000.0
# 14496      1164.0       443.0         5.1020            417500.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND
# 2728                       False                    True  \
# 5597                       False                   False
# 8974                        True                   False
# 1138                       False                    True
# 14853                      False                   False
# ...                          ...                     ...
# 4837                        True                   False
# 17720                       True                   False
# 1329                       False                    True
# 13362                      False                    True
# 14496                      False                   False
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY
# 2728                    False                     False  \
# 5597                    False                     False
# 8974                    False                     False
# 1138                    False                     False
# 14853                   False                     False
# ...                       ...                       ...
# 4837                    False                     False
# 17720                   False                     False
# 1329                    False                     False
# 13362                   False                     False
# 14496                   False                     False
#
#        ocean_proximity_NEAR OCEAN
# 2728                        False
# 5597                         True
# 8974                        False
# 1138                        False
# 14853                        True
# ...                           ...
# 4837                        False
# 17720                       False
# 1329                        False
# 13362                       False
# 14496                        True
#
# [16346 rows x 14 columns]

# %%
train_data.corr(numeric_only = True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms
# longitude            1.000000 -0.924119           -0.101619     0.049913  \
# latitude            -0.924119  1.000000            0.004534    -0.039367
# housing_median_age  -0.101619  0.004534            1.000000    -0.363079
# total_rooms          0.049913 -0.039367           -0.363079     1.000000
# total_bedrooms       0.072187 -0.068138           -0.322790     0.932292
# population           0.104779 -0.113455           -0.299318     0.859718
# households           0.060001 -0.074414           -0.305185     0.920675
# median_income       -0.008775 -0.086043           -0.121394     0.201548
# median_house_value  -0.038760 -0.150385            0.105218     0.136890
#
#                     total_bedrooms  population  households  median_income
# longitude                 0.072187    0.104779    0.060001      -0.008775  \
# latitude                 -0.068138   -0.113455   -0.074414      -0.086043
# housing_median_age       -0.322790   -0.299318   -0.305185      -0.121394
# total_rooms               0.932292    0.859718    0.920675       0.201548
# total_bedrooms            1.000000    0.878599    0.979179      -0.001984
# population                0.878599    1.000000    0.909088       0.009173
# households                0.979179    0.909088    1.000000       0.019993
# median_income            -0.001984    0.009173    0.019993       1.000000
# median_house_value        0.055397   -0.019279    0.070868       0.687684
#
#                     median_house_value
# longitude                    -0.038760
# latitude                     -0.150385
# housing_median_age            0.105218
# total_rooms                   0.136890
# total_bedrooms                0.055397
# population                   -0.019279
# households                    0.070868
# median_income                 0.687684
# median_house_value            1.000000

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(numeric_only = True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7182
# INLAND        5266
# NEAR OCEAN    2093
# NEAR BAY      1802
# ISLAND           3
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 2728       False    True   False     False       False
# 5597       False   False   False     False        True
# 8974        True   False   False     False       False
# 1138       False    True   False     False       False
# 14853      False   False   False     False        True
# ...          ...     ...     ...       ...         ...
# 4837        True   False   False     False       False
# 17720       True   False   False     False       False
# 1329       False    True   False     False       False
# 13362      False    True   False     False       False
# 14496      False   False   False     False        True
#
# [16346 rows x 5 columns]

# %%
train_data.join(pd.get_dummies(train_data.ocean_proximity))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 2728     -115.55     32.79                23.0     6.912743        5.402677  \
# 5597     -118.23     33.80                26.0     5.480639        4.912655
# 8974     -118.41     34.01                26.0     7.825645        6.109248
# 1138     -121.56     39.69                 8.0     7.950502        6.259581
# 14853    -117.08     32.66                43.0     6.912743        5.468060
# ...          ...       ...                 ...          ...             ...
# 4837     -118.29     34.03                42.0     7.427144        6.324359
# 17720    -121.78     37.34                11.0     8.069655        6.018593
# 1329     -121.88     38.00                16.0     7.865572        6.089045
# 13362    -117.61     34.02                 8.0     4.158883        2.302585
# 14496    -117.19     32.85                15.0     7.971086        6.212606
#
#        population  households  median_income ocean_proximity
# 2728     6.548219    5.308268         1.6351          INLAND  \
# 5597     5.111988    4.727388         1.3333      NEAR OCEAN
# 8974     7.105786    6.056784         5.3683       <1H OCEAN
# 1138     7.059618    6.240276         3.1300          INLAND
# 14853    6.733402    5.463832         2.8100      NEAR OCEAN
# ...           ...         ...            ...             ...
# 4837     7.649693    6.267201         1.9167       <1H OCEAN
# 17720    7.481556    6.037871         7.0671       <1H OCEAN
# 1329     7.210080    6.013715         4.1947          INLAND
# 13362    3.258097    2.079442         7.7197          INLAND
# 14496    7.060476    6.095825         5.1020      NEAR OCEAN
#
#        median_house_value  <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 2728              59600.0      False    True   False     False       False
# 5597             187500.0      False   False   False     False        True
# 8974             500001.0       True   False   False     False       False
# 1138             168300.0      False    True   False     False       False
# 14853            103400.0      False   False   False     False        True
# ...                   ...        ...     ...     ...       ...         ...
# 4837             136400.0       True   False   False     False       False
# 17720            378200.0       True   False   False     False       False
# 1329             140300.0      False    True   False     False       False
# 13362            275000.0      False    True   False     False       False
# 14496            417500.0      False   False   False     False        True
#
# [16346 rows x 15 columns]

# %%
train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 2728     -115.55     32.79                23.0     6.912743        5.402677  \
# 5597     -118.23     33.80                26.0     5.480639        4.912655
# 8974     -118.41     34.01                26.0     7.825645        6.109248
# 1138     -121.56     39.69                 8.0     7.950502        6.259581
# 14853    -117.08     32.66                43.0     6.912743        5.468060
# ...          ...       ...                 ...          ...             ...
# 4837     -118.29     34.03                42.0     7.427144        6.324359
# 17720    -121.78     37.34                11.0     8.069655        6.018593
# 1329     -121.88     38.00                16.0     7.865572        6.089045
# 13362    -117.61     34.02                 8.0     4.158883        2.302585
# 14496    -117.19     32.85                15.0     7.971086        6.212606
#
#        population  households  median_income  median_house_value  <1H OCEAN
# 2728     6.548219    5.308268         1.6351             59600.0      False  \
# 5597     5.111988    4.727388         1.3333            187500.0      False
# 8974     7.105786    6.056784         5.3683            500001.0       True
# 1138     7.059618    6.240276         3.1300            168300.0      False
# 14853    6.733402    5.463832         2.8100            103400.0      False
# ...           ...         ...            ...                 ...        ...
# 4837     7.649693    6.267201         1.9167            136400.0       True
# 17720    7.481556    6.037871         7.0671            378200.0       True
# 1329     7.210080    6.013715         4.1947            140300.0      False
# 13362    3.258097    2.079442         7.7197            275000.0      False
# 14496    7.060476    6.095825         5.1020            417500.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 2728     True   False     False       False
# 5597    False   False     False        True
# 8974    False   False     False       False
# 1138     True   False     False       False
# 14853   False   False     False        True
# ...       ...     ...       ...         ...
# 4837    False   False     False       False
# 17720   False   False     False       False
# 1329     True   False     False       False
# 13362    True   False     False       False
# 14496   False   False     False        True
#
# [16346 rows x 14 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(numeric_only = True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize = (15, 8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(numeric_only = True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train = train_data.drop(['median_house_value'], axis = 1), train_data['median_house_value']

reg = LinearRegression()

reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household'] = test_data['total_rooms'] / test_data['households']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14364\2168948889.py in ?()
#       4 test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
#       5 test_data['population'] = np.log(test_data['population'] + 1)
#       6 test_data['households'] = np.log(test_data['households'] + 1)
#       7
# ----> 8 test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)
#       9
#      10 test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
#      11 test_data['household'] = test_data['total_rooms'] / test_data['households']
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ocean_proximity'

# %%
x_test, y_test = test_data.drop(['median_house_value'], axis = 1), test_data['median_house_value']

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 2728     -115.55     32.79                23.0     6.912743        5.402677  \
# 5597     -118.23     33.80                26.0     5.480639        4.912655
# 8974     -118.41     34.01                26.0     7.825645        6.109248
# 1138     -121.56     39.69                 8.0     7.950502        6.259581
# 14853    -117.08     32.66                43.0     6.912743        5.468060
# ...          ...       ...                 ...          ...             ...
# 4837     -118.29     34.03                42.0     7.427144        6.324359
# 17720    -121.78     37.34                11.0     8.069655        6.018593
# 1329     -121.88     38.00                16.0     7.865572        6.089045
# 13362    -117.61     34.02                 8.0     4.158883        2.302585
# 14496    -117.19     32.85                15.0     7.971086        6.212606
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND
# 2728     6.548219    5.308268         1.6351      False    True   False  \
# 5597     5.111988    4.727388         1.3333      False   False   False
# 8974     7.105786    6.056784         5.3683       True   False   False
# 1138     7.059618    6.240276         3.1300      False    True   False
# 14853    6.733402    5.463832         2.8100      False   False   False
# ...           ...         ...            ...        ...     ...     ...
# 4837     7.649693    6.267201         1.9167       True   False   False
# 17720    7.481556    6.037871         7.0671       True   False   False
# 1329     7.210080    6.013715         4.1947      False    True   False
# 13362    3.258097    2.079442         7.7197      False    True   False
# 14496    7.060476    6.095825         5.1020      False   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household
# 2728      False       False       0.781553   1.302260
# 5597      False        True       0.896365   1.159338
# 8974      False       False       0.780670   1.292046
# 1138      False       False       0.787319   1.274063
# 14853     False        True       0.791012   1.265182
# ...         ...         ...            ...        ...
# 4837      False       False       0.851520   1.185082
# 17720     False       False       0.745830   1.336507
# 1329      False       False       0.774139   1.307939
# 13362     False       False       0.553655   2.000000
# 14496     False        True       0.779393   1.307630
#
# [16346 rows x 15 columns]

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 11194    -117.92     33.83                 6.0     8.051022        2.066700  \
# 11618    -118.05     33.79                19.0     7.530480        1.927882
# 1634     -122.20     37.89                37.0     8.264106        1.991937
# 12964    -121.31     38.71                18.0     8.293800        2.029908
# 13350    -117.63     34.02                13.0     8.489822        2.027233
# ...          ...       ...                 ...          ...             ...
# 7861     -118.14     33.90                39.0     7.229839        1.893932
# 12587    -121.51     38.53                34.0     7.386471        1.884566
# 14981    -116.99     32.72                15.0     6.716595        1.770740
# 16465    -121.28     38.10                13.0     7.796880        1.998099
# 4709     -118.35     34.06                52.0     7.221836        1.913631
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND
# 11194    2.145577    2.048587         2.5564       True   False   False  \
# 11618    2.096748    1.911326         3.2465       True   False   False
# 1634     2.101980    1.980998         7.3195      False   False   False
# 12964    2.155971    2.014070         4.3836      False    True   False
# 13350    2.189480    2.026145         5.6168      False    True   False
# ...           ...         ...            ...        ...     ...     ...
# 7861     2.052129    1.898632         3.3375       True   False   False
# 12587    2.008065    1.885136         4.2500      False    True   False
# 14981    1.918998    1.772033         4.0391       True   False   False
# 16465    2.113092    2.002632         2.5556      False    True   False
# 4709     2.005053    1.904646         5.3819       True   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio   household  median_house_value
# 11194     False       False       0.002200  464.115936            171300.0
# 11618     False       False       0.003153  323.322351            277400.0
# 1634       True       False       0.001631  620.962460            367500.0
# 12964     False       False       0.001654  615.668548            102000.0
# 13350     False       False       0.001355  738.671844            175400.0
# ...         ...         ...            ...         ...                 ...
# 7861      False       False       0.004094  242.920523            180100.0
# 12587     False       False       0.003462  288.693076            191900.0
# 14981     False       False       0.005909  168.960366            169500.0
# 16465     False       False       0.002621  379.494277            133100.0
# 4709      False       False       0.004223  239.285180            440900.0
#
# [4087 rows x 16 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 2728     -115.55     32.79                23.0          NaN        5.402677  \
# 5597     -118.23     33.80                26.0          NaN        4.912655
# 8974     -118.41     34.01                26.0          NaN        6.109248
# 1138     -121.56     39.69                 8.0          NaN        6.259581
# 14853    -117.08     32.66                43.0          NaN        5.468060
# ...          ...       ...                 ...          ...             ...
# 4837     -118.29     34.03                42.0          NaN        6.324359
# 17720    -121.78     37.34                11.0          NaN        6.018593
# 1329     -121.88     38.00                16.0          NaN        6.089045
# 13362    -117.61     34.02                 8.0          NaN        2.302585
# 14496    -117.19     32.85                15.0          NaN        6.212606
#
#        population  households  median_income  median_house_value  <1H OCEAN
# 2728     6.548219    5.308268         1.6351             59600.0      False  \
# 5597     5.111988    4.727388         1.3333            187500.0      False
# 8974     7.105786    6.056784         5.3683            500001.0       True
# 1138     7.059618    6.240276         3.1300            168300.0      False
# 14853    6.733402    5.463832         2.8100            103400.0      False
# ...           ...         ...            ...                 ...        ...
# 4837     7.649693    6.267201         1.9167            136400.0       True
# 17720    7.481556    6.037871         7.0671            378200.0       True
# 1329     7.210080    6.013715         4.1947            140300.0      False
# 13362    3.258097    2.079442         7.7197            275000.0      False
# 14496    7.060476    6.095825         5.1020            417500.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household
# 2728     True   False     False       False       0.781553   1.302260
# 5597    False   False     False        True       0.896365   1.159338
# 8974    False   False     False       False       0.780670   1.292046
# 1138     True   False     False       False       0.787319   1.274063
# 14853   False   False     False        True       0.791012   1.265182
# ...       ...     ...       ...         ...            ...        ...
# 4837    False   False     False       False       0.851520   1.185082
# 17720   False   False     False       False       0.745830   1.336507
# 1329     True   False     False       False       0.774139   1.307939
# 13362    True   False     False       False       0.553655   2.000000
# 14496   False   False     False        True       0.779393   1.307630
#
# [16346 rows x 16 columns]

# %%
reg.score(x_test, y_test)
# Out:
# -2339.907100931363
